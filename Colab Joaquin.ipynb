# %% [markdown]
# <a href="https://colab.research.google.com/github/aidenisquino/modulo_1/blob/main/Colab%20Joaquin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Este es mi primer cuaderno
# Aquí voy a mezclar código markdown con operaciones matemáticas
# - sumar
# - restar
# - multiplicar
# - dividir

# %%
a=-500:500
b=a^3+a^2-5*a
c=3*a^2+2*a-5
d=6*a+2
plot(a,b,main='semestre',xlab='segundos',ylab='ganas',type="s",col='red')
plot(a,c,type='s')
plot(a,d,type='s',col='blue')
# Out:
# Plot with title “semestre”
# plot without title
# plot without title
